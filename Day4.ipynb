# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

data={
    "Age": [25, 30, None, 35],
    "Studyhours": [2, 3, None, 5],
    "Gender": ['M', 'F', 'M', 'F'],
    "Marks": [80, 85, 90, 95]
}

df = pd.DataFrame(data)
print("Original Data ")
print(df)
print(df.isnull().sum())
# Out:
# Original Data
#     Age  Studyhours Gender  Marks
# 0  25.0         2.0      M     80
# 1  30.0         3.0      F     85
# 2   NaN         NaN      M     90
# 3  35.0         5.0      F     95
# Age           1
# Studyhours    1
# Gender        0
# Marks         0
# dtype: int64

# %%
print("\nData after handling missing values")
df.fillna({"Age": df["Age"].mean(), "Studyhours": df["Studyhours"].mean()}, inplace=True)
print(df)
print("\nData after handling missing values")
print(df)
# Out:
# Data after handling missing values
#     Age  Studyhours Gender  Marks
# 0  25.0    2.000000      M     80
# 1  30.0    3.000000      F     85
# 2  30.0    3.333333      M     90
# 3  35.0    5.000000      F     95
#
# Data after handling missing values
#     Age  Studyhours Gender  Marks
# 0  25.0    2.000000      M     80
# 1  30.0    3.000000      F     85
# 2  30.0    3.333333      M     90
# 3  35.0    5.000000      F     95

# %% [markdown]
# # Setting up a neural network

# %%
import torch
if torch.cuda.is_available():
    print("CUDA is available! You can use your GPU.")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is NOT available. PyTorch will use the CPU.")
    print("If you have a compatible NVIDIA GPU, you might need to install PyTorch with CUDA support.")
# Out:
# CUDA is available! You can use your GPU.
# GPU Name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F

iris = load_iris()
X = iris.data
y = iris.target

class SimpleNN(nn.Module):
    def __init__(self, in_features=4, l1=4, l2=4, out_features=3):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(in_features, l1)
        self.fc2 = nn.Linear(l1, l2)
        self.out = nn.Linear(l2, out_features)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

model = SimpleNN()
y = iris.target

class SimpleNN(nn.Module):
    def __intit__(self,in_features=4,l1=4,l2=4,out_features=3):
        super(SimpleNN, self).__init__()
        self.fc1=nn.Linear(in_features,l1)
        self.fc2= nn.Linear(l1,l2)
        self.out=nn.Linear(l2,out_features)
    
    def forward(self,x):
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2)
        x= self.out(x)
        return x

model=SimpleNN()
